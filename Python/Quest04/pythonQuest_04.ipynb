# %% [markdown]
# <a href="https://colab.research.google.com/github/w15d0177/AIFFEL_quest_cr/blob/main/Python/Quest04/pythonQuest_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![화면 캡처 2024-08-29 101612.png](data:image/png;base64,...)

# %%
import math as m     # math 모듈을 사용한다.

# 주어진 두 개의 정수와 연산자를 사용하여 계산을 수행한다.
def Calculator(num1, num2, oper):
    if oper == '+':
        return num1 + num2
    elif oper == '-':
        return num1 - num2
    elif oper == '*':
        return num1 * num2
    elif oper == '/':
        if num2 == 0:             # 두 번째 정수가 0인 경우 오류 발생
            raise ZeroDivisionError('나누는 수는 0이 될 수 없습니다.')
        else:
            return num1 / num2
    elif oper == '**':
        return int(m.pow(num1, num2))
    else:                         # 지원하지 않는 연산자가 입력되면 오류 발생
        raise Exception('지원하지 않는 연산자를 입력하였습니다.')

# 사용자가 입력한 값이 정수인지 확인하고 정수가 입력될 때까지 반복해서 입력은 받는다.
def get_int(prompt):
    while True:
        try:
            return int(input(prompt))
        except ValueError:         # 입력값이 정수가 아닌 경우 오류 발생
            print("잘못된 입력입니다. 정수를 입력해주세요.")


while True:
    try:
        num1 = get_int("첫번째 정수를 입력하세요: ")
        num2 = get_int("두번째 정수를 입력하세요: ")
        oper = input('연산자를 입력하세요: ');
        result = print(Calculator(num1, num2, oper))

    except ValueError as ve:
        print(ve)

    except ZeroDivisionError as ze:
        print(ze)

    except Exception as expt:
        print(expt)

    finally:                        # 계속 계산을 진행할지 확인한다.
        con = input("계속 진행하시겠습니까? (Y/N): ").lower()
        if con != 'y':
            print("계산기를 종료합니다.")
            break
# Out:
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: +
# 3
# 계속 진행하시겠습니까? (Y/N): y
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: -
# -1
# 계속 진행하시겠습니까? (Y/N): y
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: *
# 2
# 계속 진행하시겠습니까? (Y/N): y
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: /
# 0.5
# 계속 진행하시겠습니까? (Y/N): y
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 0
# 연산자를 입력하세요: /
# 나누는 수는 0이 될 수 없습니다.
# 계속 진행하시겠습니까? (Y/N): y
# 첫번째 정수를 입력하세요: 1.0
# 잘못된 입력입니다. 정수를 입력해주세요.
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 2.0
# 잘못된 입력입니다. 정수를 입력해주세요.
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: abc
# 지원하지 않는 연산자를 입력하였습니다.
# 계속 진행하시겠습니까? (Y/N): n
# 계산기를 종료합니다.

# %% [markdown]
# # 회고 - 최성호
#
# ● 시간이 조금 걸리긴 했지만, 지혜님과 잘 협동하여 최소한의 AI 도움을 받은 채로 문제를 해결하는 코드를 완성하게 되어 기분이 좋습니다.
# ● try - except - else - finally를 많이 활용하지는 못한 것 같은 느낌이 들어서, 나중에 예문을 좀 풀어봐야겠습니다.

# %% [markdown]
# # 회고 - 김지혜
# - 서로 문제를 해결하기 위해 의논을 많이 했습니다.
# - try-except-finally 구문을 이용하는 방향으로 코드를 짰습니다.
# - 성호님과 많은 토론을 통해 코드를 짜서 뿌듯합니다.
